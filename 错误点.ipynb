# %%
try:
    print()
except mysql.connector.Error as e:
        logger.info(f"数据库{self.database}游标对象与连接对象关闭失败")#e的作用
        return False

# %% [markdown]
#    spice_level=spice_level_mapping[item["spice_level"]]
#    取字典的成员用get

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger =logging.getLogger(__name__)
import uvicorn
def main():
    """
    启动uvicorn服务器入口
    """
    try:
        uvicorn.run("api.main:app",host="127.0.0.1",port=8000)
        logger.info("启动uvicorn服务器成功")
    except Exception as e:
        logger.info(f"启动uvicorn服务器失败异常为：{e}")
if __name__ == "__main__":
    main()#启动要加if __name__ == "__main__":才能启动

# %%
  chat_prompt = ChatPromptTemplate.from_messages([
        ("system","{system_instruction}"),
        ("human", f"{human_message}")
    ])
