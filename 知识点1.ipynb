# %% [markdown]
# logger使用
# import logging
# logging.basicConfig(level=logging.INFO)
# logger = logging.getLogger(__name__)
#
# logger.info(f"{}")

# %%
logger使用
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

logger.info(f"{}")

python里的空为none
close()
函数的使用
测试方法时直接调用即可
format_allergens = item.get('allergens') if item.get('allergens', '').strip() else "暂无过敏源"
#strip的用法
if的用法
and 、 or 、not

# %%
@app.get("/")
def  hello_world():
    """测试项目根路径访问是否可用"""
    return {"hello":"world"}
""""""加在函数体前面用于描述函数信息
请求，处理，返回

# %% [markdown]
# tab键自动对齐

# %%
 if any(keyword in user_query for keyword in delivery_keywords):循环表达式的作用

# %% [markdown]
#     res= chain.invoke({system_message:system_message, human_message:human_message})
#     return res
# 字典前一个为字符串，后一个为变量

# %%
# 获取值，键不存在则报错
name = my_dict['name']  # 返回 '张三'
age = my_dict['age']    # 返回 25

# 如果键不存在会抛出 KeyError
# my_dict['height']  # 这会报错
# 获取值
#用get方法，获取键对应的值，如果键不存在则返回None
name = my_dict.get('name')     # 返回 '张三'
age = my_dict.get('age')       # 返回 25

# %%
"\n".join([f"- {content}" for content in similar_result["contents"]])
#把列表中的字符串用换行符连接
